# %% [markdown]
# #### Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
import sys
from datetime import datetime
from scipy import stats

# %%
def WriteJSON(obj,filename):
    with open(filename, 'w+') as outfile:
        try:
            obj_json = json.dumps(obj, sort_keys=True, indent=4,default=str)
            outfile.write(obj_json)
        except Exception as e:
            print(e, file=sys.stderr)
            print('File not written.')

# %%
def ReadJSON(filename):
    obj = []
    try: 
        with open(filename, 'r') as infile:
            obj = json.load(infile)
    except Exception as e:
        print(e, file=sys.stderr)
        print('File not found.')
        
    return obj

# %% [markdown]
# ### Start Program

# %%
filename = '../data/results/results.json'
results = pd.read_json(filename)

# flatten counts, classifiers

counts = results['Counts']
Counts_0 = []
Counts_1 = []
for count in counts:
    Counts_0.append(count['0'])
    Counts_1.append(count['1'])

results['Counts_0'] = Counts_0
results['Counts_1'] = Counts_1

results = results.drop(columns=['Counts'])

allclfs = results['classifiers']
BGN = []
DTC = []
KNN = []
SVM = []
collector = [BGN,DTC,KNN,SVM]
i = 0
for clasifiers in allclfs:
    for clf in clasifiers:
        tmp = list(clf.keys())[0]
    #     print(tmp)
#         print(tmp,'Accuracy Score:',clf[tmp]['Report']['accuracy'])
        collector[i].append(clf[tmp]['Report']['accuracy'])
        if i < 3:
            i += 1
        else:
            i = 0
        
results['BGN-Accu'] = collector[0]
results['DTC-Accu'] = collector[1]
results['KNN-Accu'] = collector[2]
results['SVM-Accu'] = collector[3]


allclfs = results['classifiers']

BGNTN = []
BGNFP = []
BGNFN = []
BGNTP = []

DTCTN = []
DTCFP = []
DTCFN = []
DTCTP = []

KNNTN = []
KNNFP = []
KNNFN = []
KNNTP = []

SVMTN = []
SVMFP = []
SVMFN = []
SVMTP = []
for clasifiers in allclfs:
    for clf in clasifiers:
        tmp = list(clf.keys())[0]
        tmp2 = clf[tmp]['Matrix']
#         print(tmp)
        if tmp == 'BGN':
            tn = int(list(tmp2)[0][1:3])
            BGNTN.append(tn)
            fp = int(list(tmp2)[0][4:6])
            BGNFP.append(fp)
            fn = int(list(tmp2)[1][1:3])
            BGNFN.append(fn)
            tp = int(list(tmp2)[1][4:6])
            BGNTP.append(tp)
        elif tmp == 'DTC':
            tn = int(list(tmp2)[0][1:3])
            DTCTN.append(tn)
            fp = int(list(tmp2)[0][4:6])
            DTCFP.append(fp)
            fn = int(list(tmp2)[1][1:3])
            DTCFN.append(fn)
            tp = int(list(tmp2)[1][4:6])
            DTCTP.append(tp)
        elif tmp == 'KNN':
            tn = int(list(tmp2)[0][1:3])
            KNNTN.append(tn)
            fp = int(list(tmp2)[0][4:6])
            KNNFP.append(fp)
            fn = int(list(tmp2)[1][1:3])
            KNNFN.append(fn)
            tp = int(list(tmp2)[1][4:6])
            KNNTP.append(tp)
        elif tmp == 'SVM':
            tn = int(list(tmp2)[0][1:3])
            SVMTN.append(tn)
            fp = int(list(tmp2)[0][4:6])
            SVMFP.append(fp)
            fn = int(list(tmp2)[1][1:3])
            SVMFN.append(fn)
            tp = int(list(tmp2)[1][4:6])
            SVMTP.append(tp)


results['BGN-TN'] = BGNTN
results['BGN-FP'] = BGNFP
results['BGN-FN'] = BGNFN
results['BGN-TP'] = BGNTP

results['DTC-TN'] = DTCTN
results['DTC-FP'] = DTCFP
results['DTC-FN'] = DTCFN
results['DTC-TP'] = DTCTP

results['KNN-TN'] = KNNTN
results['KNN-FP'] = KNNFP
results['KNN-FN'] = KNNFN
results['KNN-TP'] = KNNTP

results['SVM-TN'] = SVMTN
results['SVM-FP'] = SVMFP
results['SVM-FN'] = SVMFN
results['SVM-TP'] = SVMTP

# results = results.drop(columns=['classifiers'])

# cols = ['Description', 'Image Resolution', 'Run Time', 'Sample Size',
#        'classifiers', 'Counts_0', 'Counts_1]


results
# Out:
#                                        Description Image Resolution  \
# 0                 Baseline with all 10 image sets.       [640, 640]
# 1                                      Remove AUS.       [640, 640]
# 2                                      Remove GRM.       [640, 640]
# 3                                      Remove NEW.       [640, 640]
# 4                                      Remove SWZ.       [640, 640]
# 5                                      Remove AMT.       [640, 640]
# 6                                      Remove BOS.       [640, 640]
# 7                                      Remove DEN.       [640, 640]
# 8                                      Remove LAA.       [640, 640]
# 9                                      Remove SEA.       [640, 640]
# 10                                     Remove NET.       [640, 640]
# 11         All ten image sets. Quarter resolution.       [320, 320]
# 12  All ten image sets. Three quarters resolution.       [960, 960]
#
#                 Run Time  Sample Size  \
# 0   07/22/2019, 10:27:00          0.5
# 1   07/22/2019, 10:34:11          0.5
# 2   07/22/2019, 10:46:46          0.5
# 3   07/22/2019, 10:55:12          0.5
# 4   07/22/2019, 11:01:06          0.5
# 5   07/22/2019, 11:57:51          0.5
# 6   07/22/2019, 12:09:24          0.5
# 7   07/22/2019, 12:16:53          0.5
# 8   07/22/2019, 12:27:40          0.5
# 9   07/22/2019, 12:44:16          0.5
# 10  07/22/2019, 12:51:29          0.5
# 11  07/22/2019, 12:57:07          0.5
# 12  07/22/2019, 13:17:13          0.5
#
#                                           classifiers Counts_0 Counts_1  \
# 0   [{'BGN': {'Matrix': ['[17 11]', '[14 22]'], 'R...      160      160
# 1   [{'BGN': {'Matrix': ['[14 14]', '[10 18]'], 'R...      140      140
# 2   [{'BGN': {'Matrix': ['[11 18]', '[15 20]'], 'R...      159      159
# 3   [{'BGN': {'Matrix': ['[10 19]', '[10 19]'], 'R...      145      145
# 4   [{'BGN': {'Matrix': ['[15 12]', '[13 14]'], 'R...      134      134
# 5   [{'BGN': {'Matrix': ['[ 9 13]', '[13 22]'], 'R...      142      142
# 6   [{'BGN': {'Matrix': ['[18 12]', '[12 22]'], 'R...      160      160
# 7   [{'BGN': {'Matrix': ['[14 16]', '[15 13]'], 'R...      144      144
# 8   [{'BGN': {'Matrix': ['[21  4]', '[16 19]'], 'R...      149      149
# 9   [{'BGN': {'Matrix': ['[10 19]', '[10 21]'], 'R...      150      150
# 10  [{'BGN': {'Matrix': ['[14 12]', '[14 17]'], 'R...      141      141
# 11  [{'BGN': {'Matrix': ['[ 7 20]', '[11 22]'], 'R...      149      149
# 12  [{'BGN': {'Matrix': ['[11 16]', '[10 20]'], 'R...      141      141
#
#     BGN-Accu  DTC-Accu  KNN-Accu  SVM-Accu
# 0   0.609375  0.593750  0.609375  0.437500
# 1   0.571429  0.589286  0.535714  0.517857
# 2   0.484375  0.593750  0.546875  0.453125
# 3   0.500000  0.603448  0.517241  0.500000
# 4   0.537037  0.592593  0.592593  0.500000
# 5   0.543860  0.578947  0.526316  0.385965
# 6   0.625000  0.671875  0.468750  0.468750
# 7   0.465517  0.637931  0.568966  0.482759
# 8   0.666667  0.633333  0.516667  0.416667
# 9   0.516667  0.583333  0.500000  0.483333
# 10  0.543860  0.456140  0.508772  0.456140
# 11  0.483333  0.533333  0.466667  0.450000
# 12  0.543860  0.649123  0.491228  0.473684

# %%
cols = [11,12]
results = results.drop(index=cols)
results
# Out:
#                          Description Image Resolution              Run Time  \
# 0   Baseline with all 10 image sets.       [640, 640]  07/22/2019, 10:27:00
# 1                        Remove AUS.       [640, 640]  07/22/2019, 10:34:11
# 2                        Remove GRM.       [640, 640]  07/22/2019, 10:46:46
# 3                        Remove NEW.       [640, 640]  07/22/2019, 10:55:12
# 4                        Remove SWZ.       [640, 640]  07/22/2019, 11:01:06
# 5                        Remove AMT.       [640, 640]  07/22/2019, 11:57:51
# 6                        Remove BOS.       [640, 640]  07/22/2019, 12:09:24
# 7                        Remove DEN.       [640, 640]  07/22/2019, 12:16:53
# 8                        Remove LAA.       [640, 640]  07/22/2019, 12:27:40
# 9                        Remove SEA.       [640, 640]  07/22/2019, 12:44:16
# 10                       Remove NET.       [640, 640]  07/22/2019, 12:51:29
#
#     Sample Size                                        classifiers Counts_0  \
# 0           0.5  [{'BGN': {'Matrix': ['[17 11]', '[14 22]'], 'R...      160
# 1           0.5  [{'BGN': {'Matrix': ['[14 14]', '[10 18]'], 'R...      140
# 2           0.5  [{'BGN': {'Matrix': ['[11 18]', '[15 20]'], 'R...      159
# 3           0.5  [{'BGN': {'Matrix': ['[10 19]', '[10 19]'], 'R...      145
# 4           0.5  [{'BGN': {'Matrix': ['[15 12]', '[13 14]'], 'R...      134
# 5           0.5  [{'BGN': {'Matrix': ['[ 9 13]', '[13 22]'], 'R...      142
# 6           0.5  [{'BGN': {'Matrix': ['[18 12]', '[12 22]'], 'R...      160
# 7           0.5  [{'BGN': {'Matrix': ['[14 16]', '[15 13]'], 'R...      144
# 8           0.5  [{'BGN': {'Matrix': ['[21  4]', '[16 19]'], 'R...      149
# 9           0.5  [{'BGN': {'Matrix': ['[10 19]', '[10 21]'], 'R...      150
# 10          0.5  [{'BGN': {'Matrix': ['[14 12]', '[14 17]'], 'R...      141
#
#    Counts_1  BGN-Accu  DTC-Accu  KNN-Accu  SVM-Accu
# 0       160  0.609375  0.593750  0.609375  0.437500
# 1       140  0.571429  0.589286  0.535714  0.517857
# 2       159  0.484375  0.593750  0.546875  0.453125
# 3       145  0.500000  0.603448  0.517241  0.500000
# 4       134  0.537037  0.592593  0.592593  0.500000
# 5       142  0.543860  0.578947  0.526316  0.385965
# 6       160  0.625000  0.671875  0.468750  0.468750
# 7       144  0.465517  0.637931  0.568966  0.482759
# 8       149  0.666667  0.633333  0.516667  0.416667
# 9       150  0.516667  0.583333  0.500000  0.483333
# 10      141  0.543860  0.456140  0.508772  0.456140

# %%
cols = [0,11,12]
results = results.iloc[cols]
results
# Out:
#                                        Description Image Resolution  \
# 0                 Baseline with all 10 image sets.       [640, 640]
# 11         All ten image sets. Quarter resolution.       [320, 320]
# 12  All ten image sets. Three quarters resolution.       [960, 960]
#
#                 Run Time  Sample Size  \
# 0   07/22/2019, 10:27:00          0.5
# 11  07/22/2019, 12:57:07          0.5
# 12  07/22/2019, 13:17:13          0.5
#
#                                           classifiers Counts_0 Counts_1  \
# 0   [{'BGN': {'Matrix': ['[17 11]', '[14 22]'], 'R...      160      160
# 11  [{'BGN': {'Matrix': ['[ 7 20]', '[11 22]'], 'R...      149      149
# 12  [{'BGN': {'Matrix': ['[11 16]', '[10 20]'], 'R...      141      141
#
#     BGN-Accu  DTC-Accu  KNN-Accu  SVM-Accu
# 0   0.609375  0.593750  0.609375  0.437500
# 11  0.483333  0.533333  0.466667  0.450000
# 12  0.543860  0.649123  0.491228  0.473684

# %%
results.describe()
# Out:
#        Sample Size   BGN-Accu   DTC-Accu   KNN-Accu   SVM-Accu
# count         11.0  11.000000  11.000000  11.000000  11.000000
# mean           0.5   0.551253   0.594035   0.535570   0.463827
# std            0.0   0.062050   0.053852   0.041436   0.039310
# min            0.5   0.465517   0.456140   0.468750   0.385965
# 25%            0.5   0.508333   0.586310   0.512719   0.445312
# 50%            0.5   0.543860   0.593750   0.526316   0.468750
# 75%            0.5   0.590402   0.618391   0.557920   0.491667
# max            0.5   0.666667   0.671875   0.609375   0.517857

# %%
stats.zscore(results['BGN-Accu'])
# Out:
# array([ 0.9824125 ,  0.34101698, -1.13041981, -0.86631577, -0.24029138,
#        -0.1249711 ,  1.24651654, -1.44916606,  1.95079398, -0.58460479,
#        -0.1249711 ])

# %%
stats.zscore(results['DTC-Accu'])
# Out:
# array([-0.0055541 , -0.09249886, -0.0055541 ,  0.18332589, -0.02809533,
#        -0.29384461,  1.51597915,  0.85489919,  0.76535608, -0.2084252 ,
#        -2.68558811])

# %%
stats.zscore(results['KNN-Accu'])
# Out:
# array([ 1.86814365,  0.00365637,  0.28615444, -0.46392665,  1.44335025,
#        -0.23423675, -1.69133207,  0.8453058 , -0.47847368, -0.90033747,
#        -0.67830389])

# %%
stats.zscore(results['SVM-Accu'])
# Out:
# array([-0.70241553,  1.44155434, -0.2855325 ,  0.96511659,  0.96511659,
#        -2.07739816,  0.13135053,  0.50510773, -1.25825957,  0.52044136,
#        -0.20508139])

# %%
allclfs = results['classifiers']

BGNTN = []
BGNFP = []
BGNFN = []
BGNTP = []

DTCTN = []
DTCFP = []
DTCFN = []
DTCTP = []

KNNTN = []
KNNFP = []
KNNFN = []
KNNTP = []

SVMTN = []
SVMFP = []
SVMFN = []
SVMTP = []
for clasifiers in allclfs:
    for clf in clasifiers:
        tmp = list(clf.keys())[0]
        tmp2 = clf[tmp]['Matrix']
#         print(tmp)
        if tmp == 'BGN':
            tn = int(list(tmp2)[0][1:3])
            BGNTN.append(tn)
            fp = int(list(tmp2)[0][4:6])
            BGNFP.append(fp)
            fn = int(list(tmp2)[1][1:3])
            BGNFN.append(fn)
            tp = int(list(tmp2)[1][4:6])
            BGNTP.append(tp)
        elif tmp == 'DTC':
            tn = int(list(tmp2)[0][1:3])
            DTCTN.append(tn)
            fp = int(list(tmp2)[0][4:6])
            DTCFP.append(fp)
            fn = int(list(tmp2)[1][1:3])
            DTCFN.append(fn)
            tp = int(list(tmp2)[1][4:6])
            DTCTP.append(tp)
        elif tmp == 'KNN':
            tn = int(list(tmp2)[0][1:3])
            KNNTN.append(tn)
            fp = int(list(tmp2)[0][4:6])
            KNNFP.append(fp)
            fn = int(list(tmp2)[1][1:3])
            KNNFN.append(fn)
            tp = int(list(tmp2)[1][4:6])
            KNNTP.append(tp)
        elif tmp == 'SVM':
            tn = int(list(tmp2)[0][1:3])
            SVMTN.append(tn)
            fp = int(list(tmp2)[0][4:6])
            SVMFP.append(fp)
            fn = int(list(tmp2)[1][1:3])
            SVMFN.append(fn)
            tp = int(list(tmp2)[1][4:6])
            SVMTP.append(tp)


results['BGN-TN'] = BGNTN
results['BGN-FP'] = BGNFP
results['BGN-FN'] = BGNFN
results['BGN-TP'] = BGNTP

results['DTC-TN'] = DTCTN
results['DTC-FP'] = DTCFP
results['DTC-FN'] = DTCFN
results['DTC-TP'] = DTCTP

results['KNN-TN'] = KNNTN
results['KNN-FP'] = KNNFP
results['KNN-FN'] = KNNFN
results['KNN-TP'] = KNNTP

results['SVM-TN'] = SVMTN
results['SVM-FP'] = SVMFP
results['SVM-FN'] = SVMFN
results['SVM-TP'] = SVMTP
