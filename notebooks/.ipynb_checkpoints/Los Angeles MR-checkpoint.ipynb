# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import mapping
import folium
import gmaps
import os
import requests
import shutil

# %%
with open('../resources/key.txt') as f:
    token = f.read()
    
gmaps.configure(api_key = token)

# %%
input_folder = '../data/railways/Amtrak_Routes/'
input_file = input_folder+'Amtrak_Routes.shp'

output_folder = '../data/output_images/China/'
output_csv = output_folder+'AMT.csv'

# %% [markdown]
# ### Import Routes

# %%
blue = gpd.read_file('LAMR/801_Blue_Track/801_Track_0316.shp')
blue = blue.to_crs({'init' :'epsg:4269'})

red = gpd.read_file('LAMR/802_Red_Purple_Track/802_805_Track_0316.shp')
red = red.to_crs({'init' :'epsg:4269'})

green = gpd.read_file('LAMR/803_Green_Track/803_Track_0316.shp')
green = green.to_crs({'init' :'epsg:4269'})

gold = gpd.read_file('LAMR/804_Gold_Track/804_Track_0316.shp')
gold = gold.to_crs({'init' :'epsg:4269'})

expo = gpd.read_file('LAMR/806_Expo_Track/806_Track_0316.shp')
expo = expo.to_crs({'init' :'epsg:4269'})

frames = [blue,red,green,gold,expo]

routes = gpd.GeoDataFrame(pd.concat(frames, ignore_index=True) )

routes.head()
# Out:
# /Users/jessedecker/miniconda3/envs/geo1/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#     Id  OBJECTID  SHAPE_Leng  \
# 0  0.0       NaN         NaN
# 1  0.0       NaN         NaN
# 2  0.0       NaN         NaN
# 3  0.0       NaN         NaN
# 4  0.0       NaN         NaN
#
#                                             geometry
# 0  LINESTRING (-118.1893707098661 33.777799051058...
# 1  LINESTRING (-118.1937438467048 33.776128475602...
# 2  LINESTRING (-118.1937438467048 33.776128475602...
# 3  LINESTRING (-118.1937425194715 33.768454143462...
# 4  LINESTRING (-118.1929738864244 33.767995720331...

# %%
routes.shape
# Out:
# (480, 4)

# %%
'''
Get all points
'''

points = []
for i in range(0,len(routes.index.tolist())):
    try:
        route = routes.iloc[i]
        g = [m for m in route.geometry]
        for j in range(0,len(g)):
            sec_points = mapping(g[j])["coordinates"]
            for k in range(0,len(sec_points)):
                points.append(sec_points[k])
    except Exception as e:
        print("Skipped route number",i,'because',e)

print(len(points),'points')
# Out:
# Skipped route number 0 because 'LineString' object is not iterable
# Skipped route number 1 because 'LineString' object is not iterable
# Skipped route number 2 because 'LineString' object is not iterable
# Skipped route number 3 because 'LineString' object is not iterable
# Skipped route number 4 because 'LineString' object is not iterable
# Skipped route number 5 because 'LineString' object is not iterable
# Skipped route number 6 because 'LineString' object is not iterable
# Skipped route number 7 because 'LineString' object is not iterable
# Skipped route number 8 because 'LineString' object is not iterable
# Skipped route number 9 because 'LineString' object is not iterable
# Skipped route number 10 because 'LineString' object is not iterable
# Skipped route number 11 because 'LineString' object is not iterable
# Skipped route number 12 because 'LineString' object is not iterable
# Skipped route number 13 because 'LineString' object is not iterable
# Skipped route number 14 because 'LineString' object is not iterable
# Skipped route number 15 because 'LineString' object is not iterable
# Skipped route number 16 because 'LineString' object is not iterable
# Skipped route number 17 because 'LineString' object is not iterable
# Skipped route number 18 because 'LineString' object is not iterable
# Skipped route number 19 because 'LineString' object is not iterable
# Skipped route number 20 because 'LineString' object is not iterable
# Skipped route number 21 because 'LineString' object is not iterable
# Skipped route number 22 because 'LineString' object is not iterable
# Skipped route number 23 because 'LineString' object is not iterable
# Skipped route number 24 because 'LineString' object is not iterable
# Skipped route number 25 because 'LineString' object is not iterable
# Skipped route number 26 because 'LineString' object is not iterable
# Skipped route number 27 because 'LineString' object is not iterable
# Skipped route number 28 because 'LineString' object is not iterable
# Skipped route number 29 because 'LineString' object is not iterable
# Skipped route number 30 because 'LineString' object is not iterable
# Skipped route number 31 because 'LineString' object is not iterable
# Skipped route number 32 because 'LineString' object is not iterable
# Skipped route number 33 because 'LineString' object is not iterable
# Skipped route number 34 because 'LineString' object is not iterable
# Skipped route number 35 because 'LineString' object is not iterable
# Skipped route number 36 because 'LineString' object is not iterable
# Skipped route number 37 because 'LineString' object is not iterable
# Skipped route number 38 because 'LineString' object is not iterable
# Skipped route number 39 because 'LineString' object is not iterable
# Skipped route number 40 because 'LineString' object is not iterable
# Skipped route number 41 because 'LineString' object is not iterable
# Skipped route number 42 because 'LineString' object is not iterable
# Skipped route number 43 because 'LineString' object is not iterable
# Skipped route number 44 because 'LineString' object is not iterable
# Skipped route number 45 because 'LineString' object is not iterable
# Skipped route number 46 because 'LineString' object is not iterable
# Skipped route number 47 because 'LineString' object is not iterable
# Skipped route number 48 because 'LineString' object is not iterable
# Skipped route number 49 because 'LineString' object is not iterable
# Skipped route number 50 because 'LineString' object is not iterable
# Skipped route number 51 because 'LineString' object is not iterable
# Skipped route number 52 because 'LineString' object is not iterable
# Skipped route number 53 because 'LineString' object is not iterable
# Skipped route number 54 because 'LineString' object is not iterable
# Skipped route number 55 because 'LineString' object is not iterable
# Skipped route number 56 because 'LineString' object is not iterable
# Skipped route number 57 because 'LineString' object is not iterable
# Skipped route number 58 because 'LineString' object is not iterable
# Skipped route number 59 because 'LineString' object is not iterable
# Skipped route number 60 because 'LineString' object is not iterable
# Skipped route number 61 because 'LineString' object is not iterable
# Skipped route number 62 because 'LineString' object is not iterable
# Skipped route number 63 because 'LineString' object is not iterable
# Skipped route number 64 because 'LineString' object is not iterable
# Skipped route number 65 because 'LineString' object is not iterable
# Skipped route number 66 because 'LineString' object is not iterable
# Skipped route number 67 because 'LineString' object is not iterable
# Skipped route number 68 because 'LineString' object is not iterable
# Skipped route number 69 because 'LineString' object is not iterable
# Skipped route number 70 because 'LineString' object is not iterable
# Skipped route number 71 because 'LineString' object is not iterable
# Skipped route number 72 because 'LineString' object is not iterable
# Skipped route number 73 because 'LineString' object is not iterable
# Skipped route number 74 because 'LineString' object is not iterable
# Skipped route number 75 because 'LineString' object is not iterable
# Skipped route number 76 because 'LineString' object is not iterable
# Skipped route number 77 because 'LineString' object is not iterable
# Skipped route number 78 because 'LineString' object is not iterable
# Skipped route number 79 because 'LineString' object is not iterable
# Skipped route number 80 because 'LineString' object is not iterable
# Skipped route number 81 because 'LineString' object is not iterable
# Skipped route number 82 because 'LineString' object is not iterable
# Skipped route number 83 because 'LineString' object is not iterable
# Skipped route number 84 because 'LineString' object is not iterable
# Skipped route number 85 because 'LineString' object is not iterable
# Skipped route number 86 because 'LineString' object is not iterable
# Skipped route number 87 because 'LineString' object is not iterable
# Skipped route number 88 because 'LineString' object is not iterable
# Skipped route number 89 because 'LineString' object is not iterable
# Skipped route number 90 because 'LineString' object is not iterable
# Skipped route number 91 because 'LineString' object is not iterable
# Skipped route number 92 because 'LineString' object is not iterable
# Skipped route number 93 because 'LineString' object is not iterable
# Skipped route number 94 because 'LineString' object is not iterable
# Skipped route number 95 because 'LineString' object is not iterable
# Skipped route number 96 because 'LineString' object is not iterable
# Skipped route number 97 because 'LineString' object is not iterable
# Skipped route number 98 because 'LineString' object is not iterable
# Skipped route number 99 because 'LineString' object is not iterable
# Skipped route number 100 because 'LineString' object is not iterable
# Skipped route number 101 because 'LineString' object is not iterable
# Skipped route number 102 because 'LineString' object is not iterable
# Skipped route number 103 because 'LineString' object is not iterable
# Skipped route number 104 because 'LineString' object is not iterable
# Skipped route number 105 because 'LineString' object is not iterable
# Skipped route number 106 because 'LineString' object is not iterable
# Skipped route number 107 because 'LineString' object is not iterable
# Skipped route number 108 because 'LineString' object is not iterable
# Skipped route number 109 because 'LineString' object is not iterable
# Skipped route number 110 because 'LineString' object is not iterable
# Skipped route number 111 because 'LineString' object is not iterable
# Skipped route number 112 because 'LineString' object is not iterable
# Skipped route number 113 because 'LineString' object is not iterable
# Skipped route number 114 because 'LineString' object is not iterable
# Skipped route number 115 because 'LineString' object is not iterable
# Skipped route number 116 because 'LineString' object is not iterable
# Skipped route number 117 because 'LineString' object is not iterable
# Skipped route number 118 because 'LineString' object is not iterable
# Skipped route number 119 because 'LineString' object is not iterable
# Skipped route number 120 because 'LineString' object is not iterable
# Skipped route number 121 because 'LineString' object is not iterable
# Skipped route number 122 because 'LineString' object is not iterable
# Skipped route number 123 because 'LineString' object is not iterable
# Skipped route number 124 because 'LineString' object is not iterable
# Skipped route number 125 because 'LineString' object is not iterable
# Skipped route number 126 because 'LineString' object is not iterable
# Skipped route number 127 because 'LineString' object is not iterable
# Skipped route number 128 because 'LineString' object is not iterable
# Skipped route number 129 because 'LineString' object is not iterable
# Skipped route number 130 because 'LineString' object is not iterable
# Skipped route number 131 because 'LineString' object is not iterable
# Skipped route number 132 because 'LineString' object is not iterable
# Skipped route number 133 because 'LineString' object is not iterable
# Skipped route number 134 because 'LineString' object is not iterable
# Skipped route number 135 because 'LineString' object is not iterable
# Skipped route number 136 because 'LineString' object is not iterable
# Skipped route number 137 because 'LineString' object is not iterable
# Skipped route number 138 because 'LineString' object is not iterable
# Skipped route number 139 because 'LineString' object is not iterable
# Skipped route number 140 because 'LineString' object is not iterable
# Skipped route number 141 because 'LineString' object is not iterable
# Skipped route number 142 because 'LineString' object is not iterable
# Skipped route number 143 because 'LineString' object is not iterable
# Skipped route number 144 because 'LineString' object is not iterable
# Skipped route number 145 because 'LineString' object is not iterable
# Skipped route number 146 because 'LineString' object is not iterable
# Skipped route number 147 because 'LineString' object is not iterable
# Skipped route number 148 because 'LineString' object is not iterable
# Skipped route number 149 because 'LineString' object is not iterable
# Skipped route number 150 because 'LineString' object is not iterable
# Skipped route number 151 because 'LineString' object is not iterable
# Skipped route number 152 because 'LineString' object is not iterable
# Skipped route number 153 because 'LineString' object is not iterable
# Skipped route number 154 because 'LineString' object is not iterable
# Skipped route number 155 because 'LineString' object is not iterable
# Skipped route number 156 because 'LineString' object is not iterable
# Skipped route number 157 because 'LineString' object is not iterable
# Skipped route number 158 because 'LineString' object is not iterable
# Skipped route number 159 because 'LineString' object is not iterable
# Skipped route number 160 because 'LineString' object is not iterable
# Skipped route number 161 because 'LineString' object is not iterable
# Skipped route number 162 because 'LineString' object is not iterable
# Skipped route number 163 because 'LineString' object is not iterable
# Skipped route number 164 because 'LineString' object is not iterable
# Skipped route number 165 because 'LineString' object is not iterable
# Skipped route number 166 because 'LineString' object is not iterable
# Skipped route number 167 because 'LineString' object is not iterable
# Skipped route number 168 because 'LineString' object is not iterable
# Skipped route number 169 because 'LineString' object is not iterable
# Skipped route number 170 because 'LineString' object is not iterable
# Skipped route number 171 because 'LineString' object is not iterable
# Skipped route number 172 because 'LineString' object is not iterable
# Skipped route number 173 because 'LineString' object is not iterable
# Skipped route number 174 because 'LineString' object is not iterable
# Skipped route number 175 because 'LineString' object is not iterable
# Skipped route number 176 because 'LineString' object is not iterable
# Skipped route number 177 because 'LineString' object is not iterable
# Skipped route number 178 because 'LineString' object is not iterable
# Skipped route number 179 because 'LineString' object is not iterable
# Skipped route number 180 because 'LineString' object is not iterable
# Skipped route number 181 because 'LineString' object is not iterable
# Skipped route number 182 because 'LineString' object is not iterable
# Skipped route number 183 because 'LineString' object is not iterable
# Skipped route number 184 because 'LineString' object is not iterable
# Skipped route number 185 because 'LineString' object is not iterable
# Skipped route number 186 because 'LineString' object is not iterable
# Skipped route number 187 because 'LineString' object is not iterable
# Skipped route number 188 because 'LineString' object is not iterable
# Skipped route number 189 because 'LineString' object is not iterable
# Skipped route number 190 because 'LineString' object is not iterable
# Skipped route number 191 because 'LineString' object is not iterable
# Skipped route number 192 because 'LineString' object is not iterable
# Skipped route number 193 because 'LineString' object is not iterable
# Skipped route number 194 because 'LineString' object is not iterable
# Skipped route number 195 because 'LineString' object is not iterable
# Skipped route number 196 because 'LineString' object is not iterable
# Skipped route number 197 because 'LineString' object is not iterable
# Skipped route number 198 because 'LineString' object is not iterable
# Skipped route number 199 because 'LineString' object is not iterable
# Skipped route number 200 because 'LineString' object is not iterable
# Skipped route number 201 because 'LineString' object is not iterable
# Skipped route number 202 because 'LineString' object is not iterable
# Skipped route number 203 because 'LineString' object is not iterable
# Skipped route number 204 because 'LineString' object is not iterable
# Skipped route number 205 because 'LineString' object is not iterable
# Skipped route number 206 because 'LineString' object is not iterable
# Skipped route number 207 because 'LineString' object is not iterable
# Skipped route number 208 because 'LineString' object is not iterable
# Skipped route number 209 because 'LineString' object is not iterable
# Skipped route number 210 because 'LineString' object is not iterable
# Skipped route number 211 because 'LineString' object is not iterable
# Skipped route number 212 because 'LineString' object is not iterable
# Skipped route number 215 because 'LineString' object is not iterable
# Skipped route number 216 because 'LineString' object is not iterable
# Skipped route number 217 because 'LineString' object is not iterable
# Skipped route number 218 because 'LineString' object is not iterable
# Skipped route number 219 because 'LineString' object is not iterable
# Skipped route number 220 because 'LineString' object is not iterable
# Skipped route number 221 because 'LineString' object is not iterable
# Skipped route number 222 because 'LineString' object is not iterable
# Skipped route number 223 because 'LineString' object is not iterable
# Skipped route number 224 because 'LineString' object is not iterable
# Skipped route number 225 because 'LineString' object is not iterable
# Skipped route number 226 because 'LineString' object is not iterable
# Skipped route number 227 because 'LineString' object is not iterable
# Skipped route number 228 because 'LineString' object is not iterable
# Skipped route number 229 because 'LineString' object is not iterable
# Skipped route number 230 because 'LineString' object is not iterable
# Skipped route number 231 because 'LineString' object is not iterable
# Skipped route number 232 because 'LineString' object is not iterable
# Skipped route number 233 because 'LineString' object is not iterable
# Skipped route number 234 because 'LineString' object is not iterable
# Skipped route number 235 because 'LineString' object is not iterable
# Skipped route number 236 because 'LineString' object is not iterable
# Skipped route number 237 because 'LineString' object is not iterable
# Skipped route number 238 because 'LineString' object is not iterable
# Skipped route number 239 because 'LineString' object is not iterable
# Skipped route number 240 because 'LineString' object is not iterable
# Skipped route number 241 because 'LineString' object is not iterable
# Skipped route number 242 because 'LineString' object is not iterable
# Skipped route number 243 because 'LineString' object is not iterable
# Skipped route number 244 because 'LineString' object is not iterable
# Skipped route number 245 because 'LineString' object is not iterable
# Skipped route number 246 because 'LineString' object is not iterable
# Skipped route number 247 because 'LineString' object is not iterable
# Skipped route number 248 because 'LineString' object is not iterable
# Skipped route number 249 because 'LineString' object is not iterable
# Skipped route number 250 because 'LineString' object is not iterable
# Skipped route number 251 because 'LineString' object is not iterable
# Skipped route number 252 because 'LineString' object is not iterable
# Skipped route number 253 because 'LineString' object is not iterable
# Skipped route number 254 because 'LineString' object is not iterable
# Skipped route number 255 because 'LineString' object is not iterable
# Skipped route number 256 because 'LineString' object is not iterable
# Skipped route number 257 because 'LineString' object is not iterable
# Skipped route number 258 because 'LineString' object is not iterable
# Skipped route number 259 because 'LineString' object is not iterable
# Skipped route number 260 because 'LineString' object is not iterable
# Skipped route number 263 because 'LineString' object is not iterable
# Skipped route number 264 because 'LineString' object is not iterable
# Skipped route number 265 because 'LineString' object is not iterable
# Skipped route number 266 because 'LineString' object is not iterable
# Skipped route number 267 because 'LineString' object is not iterable
# Skipped route number 268 because 'LineString' object is not iterable
# Skipped route number 269 because 'LineString' object is not iterable
# Skipped route number 270 because 'LineString' object is not iterable
# Skipped route number 271 because 'LineString' object is not iterable
# Skipped route number 272 because 'LineString' object is not iterable
# Skipped route number 273 because 'LineString' object is not iterable
# Skipped route number 274 because 'LineString' object is not iterable
# Skipped route number 275 because 'LineString' object is not iterable
# Skipped route number 276 because 'LineString' object is not iterable
# Skipped route number 277 because 'LineString' object is not iterable
# Skipped route number 278 because 'LineString' object is not iterable
# Skipped route number 279 because 'LineString' object is not iterable
# Skipped route number 280 because 'LineString' object is not iterable
# Skipped route number 281 because 'LineString' object is not iterable
# Skipped route number 282 because 'LineString' object is not iterable
# Skipped route number 283 because 'LineString' object is not iterable
# Skipped route number 284 because 'LineString' object is not iterable
# Skipped route number 285 because 'LineString' object is not iterable
# Skipped route number 286 because 'LineString' object is not iterable
# Skipped route number 287 because 'LineString' object is not iterable
# Skipped route number 288 because 'LineString' object is not iterable
# Skipped route number 289 because 'LineString' object is not iterable
# Skipped route number 290 because 'LineString' object is not iterable
# Skipped route number 291 because 'LineString' object is not iterable
# Skipped route number 292 because 'LineString' object is not iterable
# Skipped route number 293 because 'LineString' object is not iterable
# Skipped route number 294 because 'LineString' object is not iterable
# Skipped route number 295 because 'LineString' object is not iterable
# Skipped route number 296 because 'LineString' object is not iterable
# Skipped route number 297 because 'LineString' object is not iterable
# Skipped route number 298 because 'LineString' object is not iterable
# Skipped route number 299 because 'LineString' object is not iterable
# Skipped route number 300 because 'LineString' object is not iterable
# Skipped route number 301 because 'LineString' object is not iterable
# Skipped route number 302 because 'LineString' object is not iterable
# Skipped route number 303 because 'LineString' object is not iterable
# Skipped route number 304 because 'LineString' object is not iterable
# Skipped route number 305 because 'LineString' object is not iterable
# Skipped route number 306 because 'LineString' object is not iterable
# Skipped route number 307 because 'LineString' object is not iterable
# Skipped route number 308 because 'LineString' object is not iterable
# Skipped route number 309 because 'LineString' object is not iterable
# Skipped route number 310 because 'LineString' object is not iterable
# Skipped route number 311 because 'LineString' object is not iterable
# Skipped route number 312 because 'LineString' object is not iterable
# Skipped route number 313 because 'LineString' object is not iterable
# Skipped route number 314 because 'LineString' object is not iterable
# Skipped route number 315 because 'LineString' object is not iterable
# Skipped route number 316 because 'LineString' object is not iterable
# Skipped route number 317 because 'LineString' object is not iterable
# Skipped route number 318 because 'LineString' object is not iterable
# Skipped route number 319 because 'LineString' object is not iterable
# Skipped route number 320 because 'LineString' object is not iterable
# Skipped route number 321 because 'LineString' object is not iterable
# Skipped route number 322 because 'LineString' object is not iterable
# Skipped route number 323 because 'LineString' object is not iterable
# Skipped route number 324 because 'LineString' object is not iterable
# Skipped route number 325 because 'LineString' object is not iterable
# Skipped route number 326 because 'LineString' object is not iterable
# Skipped route number 327 because 'LineString' object is not iterable
# Skipped route number 328 because 'LineString' object is not iterable
# Skipped route number 329 because 'LineString' object is not iterable
# Skipped route number 330 because 'LineString' object is not iterable
# Skipped route number 331 because 'LineString' object is not iterable
# Skipped route number 332 because 'LineString' object is not iterable
# Skipped route number 333 because 'LineString' object is not iterable
# Skipped route number 334 because 'LineString' object is not iterable
# Skipped route number 335 because 'LineString' object is not iterable
# Skipped route number 336 because 'LineString' object is not iterable
# Skipped route number 337 because 'LineString' object is not iterable
# Skipped route number 338 because 'LineString' object is not iterable
# Skipped route number 339 because 'LineString' object is not iterable
# Skipped route number 340 because 'LineString' object is not iterable
# Skipped route number 341 because 'LineString' object is not iterable
# Skipped route number 342 because 'LineString' object is not iterable
# Skipped route number 343 because 'LineString' object is not iterable
# Skipped route number 344 because 'LineString' object is not iterable
# Skipped route number 345 because 'LineString' object is not iterable
# Skipped route number 346 because 'LineString' object is not iterable
# Skipped route number 347 because 'LineString' object is not iterable
# Skipped route number 348 because 'LineString' object is not iterable
# Skipped route number 349 because 'LineString' object is not iterable
# Skipped route number 350 because 'LineString' object is not iterable
# Skipped route number 351 because 'LineString' object is not iterable
# Skipped route number 352 because 'LineString' object is not iterable
# Skipped route number 353 because 'LineString' object is not iterable
# Skipped route number 354 because 'LineString' object is not iterable
# Skipped route number 355 because 'LineString' object is not iterable
# Skipped route number 356 because 'LineString' object is not iterable
# Skipped route number 357 because 'LineString' object is not iterable
# Skipped route number 358 because 'LineString' object is not iterable
# Skipped route number 359 because 'LineString' object is not iterable
# Skipped route number 360 because 'LineString' object is not iterable
# Skipped route number 361 because 'LineString' object is not iterable
# Skipped route number 369 because 'LineString' object is not iterable
# Skipped route number 370 because 'LineString' object is not iterable
# Skipped route number 377 because 'LineString' object is not iterable
# Skipped route number 378 because 'LineString' object is not iterable
# Skipped route number 379 because 'LineString' object is not iterable
# Skipped route number 380 because 'LineString' object is not iterable
# Skipped route number 381 because 'LineString' object is not iterable
# Skipped route number 385 because 'LineString' object is not iterable
# Skipped route number 386 because 'LineString' object is not iterable
# Skipped route number 387 because 'LineString' object is not iterable
# Skipped route number 389 because 'LineString' object is not iterable
# Skipped route number 400 because 'LineString' object is not iterable
# Skipped route number 406 because 'LineString' object is not iterable
# Skipped route number 409 because 'LineString' object is not iterable
# Skipped route number 410 because 'LineString' object is not iterable
# Skipped route number 411 because 'LineString' object is not iterable
# Skipped route number 412 because 'LineString' object is not iterable
# Skipped route number 413 because 'LineString' object is not iterable
# Skipped route number 414 because 'LineString' object is not iterable
# Skipped route number 415 because 'LineString' object is not iterable
# Skipped route number 416 because 'LineString' object is not iterable
# Skipped route number 417 because 'LineString' object is not iterable
# Skipped route number 418 because 'LineString' object is not iterable
# Skipped route number 419 because 'LineString' object is not iterable
# Skipped route number 420 because 'LineString' object is not iterable
# Skipped route number 421 because 'LineString' object is not iterable
# Skipped route number 422 because 'LineString' object is not iterable
# Skipped route number 423 because 'LineString' object is not iterable
# Skipped route number 424 because 'LineString' object is not iterable
# Skipped route number 425 because 'LineString' object is not iterable
# Skipped route number 426 because 'LineString' object is not iterable
# Skipped route number 427 because 'LineString' object is not iterable
# Skipped route number 428 because 'LineString' object is not iterable
# Skipped route number 429 because 'LineString' object is not iterable
# Skipped route number 430 because 'LineString' object is not iterable
# Skipped route number 431 because 'LineString' object is not iterable
# Skipped route number 432 because 'LineString' object is not iterable
# Skipped route number 433 because 'LineString' object is not iterable
# Skipped route number 434 because 'LineString' object is not iterable
# Skipped route number 435 because 'LineString' object is not iterable
# Skipped route number 436 because 'LineString' object is not iterable
# Skipped route number 437 because 'LineString' object is not iterable
# Skipped route number 438 because 'LineString' object is not iterable
# Skipped route number 439 because 'LineString' object is not iterable
# Skipped route number 440 because 'LineString' object is not iterable
# Skipped route number 441 because 'LineString' object is not iterable
# Skipped route number 442 because 'LineString' object is not iterable
# Skipped route number 443 because 'LineString' object is not iterable
# Skipped route number 444 because 'LineString' object is not iterable
# Skipped route number 445 because 'LineString' object is not iterable
# Skipped route number 446 because 'LineString' object is not iterable
# Skipped route number 447 because 'LineString' object is not iterable
# Skipped route number 448 because 'LineString' object is not iterable
# Skipped route number 449 because 'LineString' object is not iterable
# Skipped route number 450 because 'LineString' object is not iterable
# Skipped route number 453 because 'LineString' object is not iterable
# Skipped route number 454 because 'LineString' object is not iterable
# Skipped route number 455 because 'LineString' object is not iterable
# Skipped route number 456 because 'LineString' object is not iterable
# Skipped route number 459 because 'LineString' object is not iterable
# Skipped route number 460 because 'LineString' object is not iterable
# Skipped route number 461 because 'LineString' object is not iterable
# Skipped route number 462 because 'LineString' object is not iterable
# Skipped route number 463 because 'LineString' object is not iterable
# Skipped route number 466 because 'LineString' object is not iterable
# Skipped route number 467 because 'LineString' object is not iterable
# Skipped route number 470 because 'LineString' object is not iterable
# Skipped route number 473 because 'LineString' object is not iterable
# Skipped route number 474 because 'LineString' object is not iterable
# Skipped route number 475 because 'LineString' object is not iterable
# Skipped route number 476 because 'LineString' object is not iterable
# Skipped route number 477 because 'LineString' object is not iterable
# Skipped route number 478 because 'LineString' object is not iterable
# Skipped route number 479 because 'LineString' object is not iterable
# 1882 points

# %%
'''
Get points for 1 or more routes
'''

rows = [0]

points = []
for i in range(0,len(routes.OBJECTID.tolist())):
    if i in rows:
    #     print('Route',i)
        try:
            route = routes.iloc[i]
            g = [m for m in route.geometry]
    #         print('\t',len(g),'sections')
            for j in range(0,len(g)):
    #             print('   section',j)
                sec_points = mapping(g[j])["coordinates"]
                for k in range(0,len(sec_points)):
    #                 print('      point',k)
                    points.append(sec_points[k])
        except Exception as e:
            print("Skipped route number",i,'because',e)

print(len(points),'points')
# Out:
# Skipped route number 0 because 'LineString' object is not iterable
# 0 points

# %%
'''
Get points for single route/section
'''

row = 0
section = 0

points = []
try:
    route = routes.iloc[row]
    g = [i for i in route.geometry]
    len(g)

    points = mapping(g[section])["coordinates"]
except Exception as e:
    print("Skipped route number",row,'because',e)
    
print(len(points),'points')
# Out:
# Skipped route number 0 because 'LineString' object is not iterable
# 0 points

# %%
'''
Get subselection of points
'''

route_points = []
for point in range(0,len(points),38):
    tmp = points[point]
    route_points.append(tmp)

print(len(route_points))
# Out:
# 50

# %%
'''
Create dataframe
'''

df = pd.DataFrame(route_points, columns=['Longitude','Latitude'])

tmp = list(df.Latitude.tolist())
names = []
for i in range(0,len(tmp)):
    name = str(df.iloc[i].Longitude)+'_'+str(df.iloc[i].Latitude)
    names.append(name)

df['Name'] = names

columns = ['Name','Longitude','Latitude']
df= df[columns]


df.head()
# Out:
#                                     Name   Longitude   Latitude
# 0  -118.25863629843894_34.04870380692666 -118.258636  34.048704
# 1    -118.2916031689273_34.0695305562798 -118.291603  34.069531
# 2  -118.29512902367632_34.10181974819955 -118.295129  34.101820
# 3   -118.3472986187191_34.10478898684855 -118.347299  34.104789
# 4   -118.3622037256695_34.14191786748499 -118.362204  34.141918

# %%
'''
Export points
'''

df.to_csv(output_csv,header=True,index=None)

# %%
'''
Plot markers
'''

# Reverse lat/lon coordinates
marker_points = []
for marker in route_points:
    marker_points.append((marker[1],marker[0]))
    
# Set map centerpoint
coords = marker_points[0]
       
# Define map
m = folium.Map(
    location = coords,
    zoom_start = 13
)
  
# Add points    
for mp in marker_points:
    folium.Marker(mp).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
'''
Get satellite preview for image
'''

row = 0

figure_layout = {
    'width': '100%',
    'height': '800px'
}
fig = gmaps.figure(center = (df.iloc[row].Latitude,df.iloc[row].Longitude), zoom_level = 19,map_type='SATELLITE',layout=figure_layout)
fig
# Out:
# Figure(layout=FigureLayout(height='800px', width='100%'))

# %%
'''
Get all images 
'''

root = os.path.dirname(os.path.abspath('Africa.ipynb'))
image_folder = root[:-9]+output_folder[3:]
image_folder

url = 'https://maps.googleapis.com/maps/api/staticmap?'
rows = df.index.tolist()
for i in range(2,len(rows)):
    row = df.iloc[i]
    center = str(row.Latitude)+','+str(row.Longitude)
    payload = {
        'center': center, 
        'zoom': 19,
        'size': '640x640',
        'scale': 2,
        'format': 'png32',
        'maptype': 'satellite',
        'key': token
    }
    
    r = requests.get(url,params=payload,stream=True)

    name = df.iloc[i]['Name']
    filename = image_folder+name+'.png'
    if r.status_code == 200:
        with open(filename, 'wb') as f:
            r.raw.decode_content = True
            shutil.copyfileobj(r.raw, f)
