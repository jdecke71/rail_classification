# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import mapping
import folium
import googlemaps
import gmaps
import os
import requests
import shutil
from IPython.display import Image

# %%
input_folder = '../data/railways/swissrail/'
input_file = input_folder+'netw_1.shp'

output_folder = '../data/output_images/Switzerland/'
output_csv = output_folder+'SWZ.csv'

update_folder = output_folder+'set_2/'

# %%
'''
Open csv with current points
'''

curr_df = pd.read_csv(output_csv)
curr_df['Name'] = curr_df['Name'].map(lambda x:x+'.png')
curr_df.head()
# Out:
#                                    Name  Longitude   Latitude  Catenary
# 0  9.379483396212201_47.565528967099404   9.379483  47.565529         1
# 1   9.367078340136002_47.57620856433524   9.367078  47.576209         1
# 2  9.347995664070325_47.583125270732666   9.347996  47.583125         1
# 3    9.32926653044524_47.59035302006366   9.329267  47.590353         1
# 4  9.311405490706957_47.598623942532434   9.311405  47.598624         1

# %%
# def TagImage():
root = os.path.dirname(os.path.abspath('untitled.ipynb'))
image_folder = root[:-9]+update_folder[3:]

names = curr_df['Name'].tolist()
for name in names[:3]:
    filename = image_folder+names[0]
    print(name)
    Image(filename)
#     print(filename)
# Out:
# 9.379483396212201_47.565528967099404.png
# 9.367078340136002_47.57620856433524.png
# 9.347995664070325_47.583125270732666.png

# %%
img = TagImage()
img

# %%
TagImage()
# tmp = input("enter something")

# %%
root = os.path.dirname(os.path.abspath('untitles.ipynb'))
image_folder = root[:-9]+update_folder[3:]
image_folder
# Out:
# '/Users/jessedecker/projects/rail_classification/data/output_images/Switzerland/set_2/'

# %%
Image()
